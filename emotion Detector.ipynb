# %%
#InstallNecessary Libraries
{
  "editable": false
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 #InstallNecessary Libraries
#       2 {
# ----> 3   "editable": false
#       4 }
#
# NameError: name 'false' is not defined

# %%
# !pip install deepface opencv-python
# Out:
# Requirement already satisfied: deepface in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (0.0.92)
# Requirement already satisfied: opencv-python in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (4.10.0.84)
# Requirement already satisfied: requests>=2.27.1 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.31.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (1.24.2)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (1.5.3)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (4.66.4)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (9.4.0)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.16.2)
# Requirement already satisfied: keras>=2.2.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (3.4.1)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (3.0.3)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (0.0.17)
# Requirement already satisfied: fire>=0.4.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (0.6.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from deepface) (22.0.0)
# Requirement already satisfied: six in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from fire>=0.4.0->deepface) (2.4.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.3)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (1.8.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: filelock in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from gdown>=3.10.1->deepface) (3.15.4)
# Requirement already satisfied: packaging in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from gunicorn>=20.1.0->deepface) (23.0)
# Requirement already satisfied: absl-py in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from keras>=2.2.0->deepface) (2.1.0)
# Requirement already satisfied: rich in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from keras>=2.2.0->deepface) (13.3.2)
# Requirement already satisfied: namex in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: h5py in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from keras>=2.2.0->deepface) (3.11.0)
# Requirement already satisfied: optree in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from keras>=2.2.0->deepface) (0.12.1)
# Requirement already satisfied: ml-dtypes in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from keras>=2.2.0->deepface) (0.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->deepface) (2022.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (2022.12.7)
# Requirement already satisfied: tensorflow-intel==2.16.2 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.16.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (58.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (1.64.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (2.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: colorama in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (0.43.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: tf-keras-nightly in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (2.18.0.dev2024070809)
# Requirement already satisfied: tf-nightly~=2.18.0.dev in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tf-keras-nightly->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (2.18.0.dev20240703)
# Requirement already satisfied: tf-nightly-intel==2.18.0-dev20240703 in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tf-nightly~=2.18.0.dev->tf-keras-nightly->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (2.18.0.dev20240703)
# Requirement already satisfied: tb-nightly~=2.18.0.a in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tf-nightly-intel==2.18.0-dev20240703->tf-nightly~=2.18.0.dev->tf-keras-nightly->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (2.18.0a20240708)
# Requirement already satisfied: keras-nightly>=3.2.0.dev in c:\users\rishendra\appdata\local\programs\python\python310\lib\site-packages (from tf-nightly-intel==2.18.0-dev20240703->tf-nightly~=2.18.0.dev->tf-keras-nightly->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow>=1.9.0->deepface) (3.4.1.dev2024070803)

# %%
import cv2
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
# Path to the video file
video_path = r'C:\Users\RISHENDRA\OneDrive\Desktop\testt.mp4'  # Replace with your video path

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Read until video is completed
while cap.isOpened():
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        break

    # Analyze the frame for emotions
    try:
        result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)
        dominant_emotion = result[0]['dominant_emotion']
        face_area = result[0]['region']  # get face coordinates

        # Draw rectangle around the face
        x, y, w, h = face_area['x'], face_area['y'], face_area['w'], face_area['h']
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Display the resulting frame with emotion
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(frame, dominant_emotion, (x, y - 10), font, 0.9, (0, 255, 0), 2, cv2.LINE_AA)
        cv2.imshow('Video', frame)
    except Exception as e:
        print("Error in analyzing frame: ", e)

    # Press Q on keyboard to exit
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

# When everything done, release the video capture object
cap.release()
cv2.destroyAllWindows()

# %%
# Path to the video file
video_path = r'C:\Users\RISHENDRA\OneDrive\Desktop\testt.mp4' 
output_path = r'C:\Users\RISHENDRA\OneDrive\Desktop\out.mp4'  # Replace with your desired output path

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Get the video writer initialized to save the output video
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, 20.0, (int(cap.get(3)), int(cap.get(4))))

# Read until video is completed
while cap.isOpened():
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        break

    # Analyze the frame for emotions
    try:
        result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)
        dominant_emotion = result[0]['dominant_emotion']
        face_area = result[0]['region']  # get face coordinates

        # Draw rectangle around the face
        x, y, w, h = face_area['x'], face_area['y'], face_area['w'], face_area['h']
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Display the resulting frame with emotion
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(frame, dominant_emotion, (x, y - 10), font, 0.9, (0, 255, 0), 2, cv2.LINE_AA)
        out.write(frame)
    except Exception as e:
        print("Error in analyzing frame: ", e)

    # Press Q on keyboard to exit
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

# When everything done, release the video capture object and video writer object
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
# Path to the video file
video_path = r'C:\Users\RISHENDRA\OneDrive\Desktop\testt.mp4'  # Replace with your video path

# Open the video file
cap = cv2.VideoCapture(video_path)

# Capture a single frame
ret, frame = cap.read()
if ret:
    # Analyze the frame for emotions
    try:
        result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)
        dominant_emotion = result[0]['dominant_emotion']
        face_area = result[0]['region']  # get face coordinates

        # Draw rectangle around the face
        x, y, w, h = face_area['x'], face_area['y'], face_area['w'], face_area['h']
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Display the resulting frame with emotion
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(frame, dominant_emotion, (x, y - 10), font, 0.9, (0, 255, 0), 2, cv2.LINE_AA)

        # Convert frame to RGB for displaying with matplotlib
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        plt.imshow(frame_rgb)
        plt.title(f"Detected Emotion: {dominant_emotion}")
        plt.axis('off')
        plt.show()
    except Exception as e:
        print("Error in analyzing frame: ", e)

# Release the video capture object
cap.release()
